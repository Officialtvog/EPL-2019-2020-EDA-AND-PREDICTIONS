# %% [markdown]
# EDA OF EPL 2019/2020
#
# TAKE NOTE;this data was before the corona virus pandemic
#
#
#
#
# HI...temitope olanipekun
#
# welcomes you to his kernel
#
# This is an EDA as regards the EPL
#
# pls as you follow along in this kernel...
#
# you would get some interetsting information as regards the EPL,before they had a break due to the corona virus

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('epl players.csv')
df.head()
# Out:
#    Unnamed: 0  assists  bonus  bps  clean_sheets  creativity  element  \
# 0           1        0      0    1             0         0.1      534
# 1           2        0      0    1             0         0.3      534
# 2           3        0      0    1             0         4.8      534
# 3           4        0      0    2             0         0.6      534
# 4           5        0      3   53             1        23.8      534
#
#    fixture  goals_conceded  goals_scored  ...  threat  total_points  \
# 0       37               1             0  ...       0             1
# 1       43               1             0  ...      21             1
# 2       58               0             0  ...      18             1
# 3       63               1             0  ...       0             1
# 4       72               0             2  ...     107            13
#
#   transfers_balance  transfers_in transfers_out  value  was_home  \
# 0                 0             0             0     45     False
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0  assists  bonus  bps  clean_sheets  creativity  element  \
# 16493       16494        0      0    0             0         0.0       27
# 16494       16495        0      0    0             0         0.0       27
# 16495       16496        0      0    0             0         0.0       27
# 16496       16497        0      0    0             0         0.0       27
# 16497       16498        0      0    0             0         0.0       27
#
#        fixture  goals_conceded  goals_scored  ...  threat  total_points  \
# 16493      231               0             0  ...       0             0
# 16494      241               0             0  ...       0             0
# 16495      252               0             0  ...       0             0
# 16496      269               0             0  ...       0             0
# 16497      285               0             0  ...       0             0
#
#       transfers_balance  transfers_in transfers_out  value  was_home  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16498 entries, 0 to 16497
# Data columns (total 34 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         16498 non-null  int64
#  1   assists            16498 non-null  int64
#  2   bonus              16498 non-null  int64
#  3   bps                16498 non-null  int64
#  4   clean_sheets       16498 non-null  int64
#  5   creativity         16498 non-null  float64
#  6   element            16498 non-null  int64
#  7   fixture            16498 non-null  int64
#  8   goals_conceded     16498 non-null  int64
#  9   goals_scored       16498 non-null  int64
#  10  ict_index          16498 non-null  float64
#  11  influence          16498 non-null  float64
#  12  kickoff_time       16498 non-null  object
#  13  minutes            16498 non-null  int64
#  14  opponent_team      16498 non-null  object
#  15  own_goals          16498 non-null  int64
# ...

# %%
df.shape
# Out:
# (16498, 34)

# %%
#The teams in the EPL
df11.team.unique()
# Out:
# array(['Brighton', 'West Ham', 'Burnley', 'Bournemouth', 'Man Utd',
#        'Watford', 'Norwich', 'Liverpool', 'Wolves', 'Chelsea', 'Everton',
#        'Aston Villa', 'Arsenal', 'Southampton', 'Tottenham',
#        'Newcastle United', 'Crystal Palace', 'Leicester', 'Man City',
#        'Sheffield United'], dtype=object)

# %%
#columns that are not needed for this EDA 
df11 = df.drop(columns = ['Unnamed: 0','bonus','kickoff_time','was_home','transfers_in','transfers_out','transfers_balance'])
df11.head()
# Out:
#    assists  bps  clean_sheets  creativity  element  fixture  goals_conceded  \
# 0        0    1             0         0.1      534       37               1
# 1        0    1             0         0.3      534       43               1
# 2        0    1             0         4.8      534       58               0
# 3        0    2             0         0.6      534       63               1
# 4        0   53             1        23.8      534       72               0
#
#    goals_scored  ict_index  influence  ...  saves selected  team_a_score  \
# 0             0        0.0        0.2  ...      0        0             0
# 1             0        2.2        1.0  ...      0    14029             1
# 2             0        2.5        2.0  ...      0    22804             0
# 3             0        0.1        0.2  ...      0    32699             0
# 4             2       20.1       70.2  ...      0    35026             0
#
# ...

# %%
#columns of the dataset
df.columns
# Out:
# Index(['Unnamed: 0', 'assists', 'bonus', 'bps', 'clean_sheets', 'creativity',
#        'element', 'fixture', 'goals_conceded', 'goals_scored', 'ict_index',
#        'influence', 'kickoff_time', 'minutes', 'opponent_team', 'own_goals',
#        'penalties_missed', 'penalties_saved', 'red_cards', 'round', 'saves',
#        'selected', 'team_a_score', 'team_h_score', 'threat', 'total_points',
#        'transfers_balance', 'transfers_in', 'transfers_out', 'value',
#        'was_home', 'yellow_cards', 'full', 'team'],
#       dtype='object')

# %%
#checking the shape after the column which snt neede has being removed
df11.shape
# Out:
# (16498, 27)

# %%
df11.isnull().sum()
# Out:
# assists             0
# bps                 0
# clean_sheets        0
# creativity          0
# element             0
# fixture             0
# goals_conceded      0
# goals_scored        0
# ict_index           0
# influence           0
# minutes             0
# opponent_team       0
# own_goals           0
# penalties_missed    0
# penalties_saved     0
# red_cards           0
# round               0
# saves               0
# selected            0
# team_a_score        0
# team_h_score        0
# threat              0
# total_points        0
# value               0
# yellow_cards        0
# full                0
# team                0
# dtype: int64

# %%
#so we are checkimg for the number of unique values
df11.nunique()
# Out:
# assists                 4
# bps                    85
# clean_sheets            2
# creativity            598
# element               628
# fixture               288
# goals_conceded         10
# goals_scored            4
# ict_index             217
# influence             381
# minutes                91
# opponent_team          20
# own_goals               2
# penalties_missed        2
# penalties_saved         3
# red_cards               2
# round                  29
# saves                  12
# selected            14859
# team_a_score            8
# team_h_score            7
# threat                124
# total_points           27
# value                  87
# yellow_cards            2
# full                  628
# team                   20
# dtype: int64

# %%
#cheking the name of players nthat we have in the dataset
df11.full.unique()
# Out:
# array(['Aaron Connolly', 'Aaron Cresswell', 'Aaron Lennon', 'Aaron Mooy',
#        'Aaron Ramsdale', 'Aaron Wan-Bissaka',
#        'Abd-Al-Ali Morakinyo Olaposi Koiki', 'Abdoulaye Doucour?',
#        'Adam Idah', 'Adam Lallana', 'Adam Masina', 'Adam Smith',
#        'Adam Webster', 'Adama Traor?',
#        'Addji Keaninkin Marc-Israel Guehi', 'Ademola Lookman',
#        'Adrian Mariappa', 'Adri?n San Miguel del Castillo',
#        'Ahmed El Mohamady', 'Ainsley Maitland-Niles', 'Akin Famewo',
#        'Albian Ajeti', 'Alex Iwobi', 'Alex McCarthy',
#        'Alex Oxlade-Chamberlain', 'Alexander Tettey',
#        'Alexandre Nascimento Costa Silva', 'Alexandre Lacazette',
#        'Alexis Mac Allister', 'Alexis S?nchez', 'Alfie Whiteman',
#        'Alireza Jahanbakhsh', 'Alisson Ramses Becker',
#        'Allan Saint-Maximin', 'Andre Gray', 'Andre Green',
#        'Andreas Christensen', 'Andreas Pereira', 'Andrew Robertson',
# ...

# %%
#general statistics
df11.describe()
# Out:
#             assists           bps  clean_sheets    creativity       element  \
# count  16498.000000  16498.000000  16498.000000  16498.000000  16498.000000
# mean       0.041278      6.305128      0.103406      5.090229    288.756152
# std        0.215326      9.789839      0.304498     11.122974    167.613261
# min        0.000000    -12.000000      0.000000      0.000000      1.000000
# 25%        0.000000      0.000000      0.000000      0.000000    144.000000
# 50%        0.000000      0.000000      0.000000      0.000000    287.000000
# 75%        0.000000     11.000000      0.000000      3.300000    433.000000
# max        3.000000     90.000000      1.000000    127.700000    631.000000
#
#             fixture  goals_conceded  goals_scored     ict_index     influence  \
# count  16498.000000    16498.000000  16498.000000  16498.000000  16498.000000
# mean     149.169596        0.522730      0.046006      1.880155      7.793454
# ...

# %%
#HEAT MAP; its shwoing the correlation btween variables
correlations = df11.corr()

fig = plt.figure(figsize=(12, 10))
sns.heatmap(correlations, annot=True, cmap='GnBu_r', center=1)

# %%
df11.groupby('full')['goals_scored'].sum().nlargest(5)
#wanting to see  players with  the highest goals..
# Out:
# full
# Jamie Vardy                  19
# Pierre-Emerick Aubameyang    17
# Mohamed Salah                16
# Sergio Ag?ero                16
# Danny Ings                   15
# Name: goals_scored, dtype: int64

# %%
df11.groupby('full')['assists'].sum().nlargest(5)
#players with the highest assist
# Out:
# full
# Kevin De Bruyne           18
# Trent Alexander-Arnold    14
# Riyad Mahrez              10
# David Silva                9
# Heung-Min Son              9
# Name: assists, dtype: int64

# %%
df11.groupby('team')['yellow_cards'].sum().nlargest(3)
# teams with  yellow cards the most
# Out:
# team
# Arsenal      63
# Tottenham    63
# Watford      61
# Name: yellow_cards, dtype: int64

# %%
df11.groupby('team')['red_cards'].sum().nlargest(3)
# teams with  red cards the most
# Out:
# team
# Arsenal        3
# Bournemouth    3
# Everton        3
# Name: red_cards, dtype: int64

# %%
#players with more creativity
df11.groupby('full')['creativity'].sum().nlargest(5)
# Out:
# full
# Kevin De Bruyne           1457.9
# James Maddison            1171.8
# Trent Alexander-Arnold    1169.3
# Name: creativity, dtype: float64

# %%
#Top 3 Goal keepers with more saves
df11.groupby('full')['saves'].sum().nlargest(3)
# Out:
# full
# Martin Dubravka    116
# Bernd Leno         104
# Aaron Ramsdale     102
# Name: saves, dtype: int64

# %%
df11.groupby('team')['goals_scored'].sum()
#wanting to see teams with the total goal scored!!!
# Out:
# team
# Arsenal             40
# Aston Villa         33
# Bournemouth         28
# Brighton            28
# Burnley             33
# Chelsea             51
# Crystal Palace      24
# Everton             35
# Leicester           56
# Liverpool           64
# Man City            68
# Man Utd             42
# Newcastle United    25
# Norwich             24
# Sheffield United    27
# Southampton         35
# Tottenham           45
# Watford             27
# West Ham            35
# Wolves              39
# Name: goals_scored, dtype: int64

# %%
df11.groupby('team')['goals_scored'].sum().nlargest(3)
#wanting to see teams with the highest goal scored!!!
# Out:
# team
# Man City     68
# Liverpool    64
# Leicester    56
# Name: goals_scored, dtype: int64

# %%
df11.groupby('team')['goals_conceded'].sum()
#wanting to see teams with the total goal concedded!!!
# Out:
# team
# Arsenal             396
# Aston Villa         616
# Bournemouth         517
# Brighton            440
# Burnley             440
# Chelsea             429
# Crystal Palace      352
# Everton             506
# Leicester           308
# Liverpool           231
# Man City            341
# Man Utd             330
# Newcastle United    451
# Norwich             572
# Sheffield United    275
# Southampton         572
# Tottenham           440
# Watford             484
# West Ham            550
# Wolves              374
# Name: goals_conceded, dtype: int64

# %%
df11.groupby('team')['goals_conceded'].sum().nlargest(3)
#wanting to see teams with the highest goal concedded!!!
# Out:
# team
# Aston Villa    616
# Norwich        572
# Southampton    572
# Name: goals_conceded, dtype: int64

# %%
df11.groupby('team')['total_points'].sum()
# teams with  yellow cards the most
# Out:
# team
# Arsenal             1117
# Aston Villa          976
# Bournemouth          965
# Brighton            1050
# Burnley             1149
# Chelsea             1248
# Crystal Palace      1098
# Everton             1080
# Leicester           1444
# Liverpool           1631
# Man City            1407
# Man Utd             1213
# Newcastle United    1115
# Norwich              953
# Sheffield United    1212
# Southampton         1045
# Tottenham           1138
# Watford             1051
# West Ham            1072
# Wolves              1228
# Name: total_points, dtype: int64

# %% [markdown]
# FETCHING STATS FOR  MOST THE TEAMS

# %%
#Fetching the data by teams
Tottenham = df11.loc[df11.team == 'Tottenham']
Tottenham.tail()
# Out:
#        assists  bps  clean_sheets  creativity  element  fixture  \
# 15847        0    0             0         0.0      339      248
# 15848        0    0             0         0.0      339      252
# 15849        0    0             0         0.0      339      263
# 15850        0    0             0         0.0      339      278
# 15851        0    0             0         0.0      339      282
#
#        goals_conceded  goals_scored  ict_index  influence  ...  saves  \
# 15847               0             0        0.0        0.0  ...      0
# 15848               0             0        0.0        0.0  ...      0
# 15849               0             0        0.0        0.0  ...      0
# 15850               0             0        0.0        0.0  ...      0
# 15851               0             0        0.0        0.0  ...      0
#
#       selected  team_a_score  team_h_score  threat  total_points  value  \
# 15847     5260             0             2       0             0     45
# ...

# %%
Tottenham.groupby('full')['goals_scored','red_cards','yellow_cards','creativity'].sum()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                 goals_scored  red_cards  yellow_cards  \
# full
# Alfie Whiteman                             0          0             0
# Bamidele Alli                              8          0             2
# Ben Davies                                 0          0             2
# Brandon Austin                             0          0             0
# Christian Eriksen                          2          0             5
# Danny Rose                                 0          0             5
# Davinson S?nchez                           0          0             5
# Eric Dier                                  0          0             4
# Erik Lamela                                2          0             3
# ...

# %%
#Fetching the data by teams
Leicester = df11.loc[df11.team == 'Leicester']
Leicester.tail()
# Out:
#        assists  bps  clean_sheets  creativity  element  fixture  \
# 16465        0   16             0         0.4      164      244
# 16466        0   28             1         1.8      164      260
# 16467        0   13             0        10.8      164      265
# 16468        0   13             0         1.4      164      277
# 16469        0   22             1         0.5      164      285
#
#        goals_conceded  goals_scored  ict_index  influence  ...  saves  \
# 16465               2             0        1.5       14.2  ...      0
# 16466               0             0        6.5       28.0  ...      0
# 16467               1             0        2.8       17.2  ...      0
# 16468               1             0        2.1       13.4  ...      0
# 16469               0             0        2.1       14.8  ...      0
#
#       selected  team_a_score  team_h_score  threat  total_points  value  \
# 16465  1242378             2             2       0             1     50
# ...

# %%
Leicester.groupby('full')['goals_scored','red_cards','yellow_cards','creativity'].sum()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                   goals_scored  red_cards  yellow_cards  \
# full
# ?aglar S?y?nc?                               1          0             4
# Andy King                                    0          0             0
# Ayoze P?rez                                  7          0             0
# Benjamin Chilwell                            2          0             2
# Christian Fuchs                              0          0             0
# Daniel Amartey                               0          0             0
# Danny Ward                                   0          0             0
# Demarai Gray                                 1          0             1
# Dennis Praet                                 1          0             2
# ...

# %%
#Fetching the data by teams
Southampton = df11.loc[df11.team == 'Southampton']
Southampton.tail()
# Out:
#        assists  bps  clean_sheets  creativity  element  fixture  \
# 16320        0    0             0         0.0      306      245
# 16321        0    0             0         0.0      306      259
# 16322        0    0             0         0.0      306      269
# 16323        0    0             0         0.0      306      280
# 16324        0    7             0         1.9      306      289
#
#        goals_conceded  goals_scored  ict_index  influence  ...  saves  \
# 16320               0             0        0.0        0.0  ...      0
# 16321               0             0        0.0        0.0  ...      0
# 16322               0             0        0.0        0.0  ...      0
# 16323               0             0        0.0        0.0  ...      0
# 16324               1             0        3.9       12.8  ...      0
#
#       selected  team_a_score  team_h_score  threat  total_points  value  \
# 16320    10211             0             4       0             0     46
# ...

# %%
Southampton.groupby('full')['goals_scored','red_cards','yellow_cards','creativity'].sum()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                        goals_scored  red_cards  yellow_cards  creativity
# full
# Alex McCarthy                     0          0             0        10.0
# Angus Gunn                        0          0             0         0.0
# C?dric Soares                     0          0             1       197.1
# Callum Slattery                   0          0             0         0.0
# Charlie Austin                    0          0             0         0.0
# Che Adams                         0          0             0       137.6
# Daniel N'Lundulu                  0          0             0         0.0
# Danny Ings                       15          0             2       268.9
# ...

# %%
#Fetching the data by teams
AstonVilla = df11.loc[df11.team == 'Aston Villa']
AstonVilla.tail()
# Out:
#        assists  bps  clean_sheets  creativity  element  fixture  \
# 16493        0    0             0         0.0       27      231
# 16494        0    0             0         0.0       27      241
# 16495        0    0             0         0.0       27      252
# 16496        0    0             0         0.0       27      269
# 16497        0    0             0         0.0       27      285
#
#        goals_conceded  goals_scored  ict_index  influence  ...  saves  \
# 16493               0             0        0.0        0.0  ...      0
# 16494               0             0        0.0        0.0  ...      0
# 16495               0             0        0.0        0.0  ...      0
# 16496               0             0        0.0        0.0  ...      0
# 16497               0             0        0.0        0.0  ...      0
#
#       selected  team_a_score  team_h_score  threat  total_points  value  \
# 16493    18002             1             2       0             0     43
# ...

# %%
AstonVilla.groupby('full')['goals_scored','red_cards','yellow_cards','creativity'].sum()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                 goals_scored  red_cards  yellow_cards  \
# full
# ?rjan Nyland                               0          0             0
# Ahmed El Mohamady                          0          0             0
# Andre Green                                0          0             0
# Anwar El Ghazi                             4          0             3
# Birkir Bjarnason                           0          0             0
# Bjorn Engels                               1          0             1
# Borja Gonz?lez Tom?s                       0          0             0
# Conor Hourihane                            3          0             4
# Daniel Drinkwater                          0          0             1
# ...

# %%
#Fetching the data by teams
Chelsea = df11.loc[df11.team == 'Chelsea']
Chelsea.tail()
# Out:
#        assists  bps  clean_sheets  creativity  element  fixture  \
# 16233        0   11             0         0.0      112      244
# 16234        0   10             0         0.0      112      254
# 16235        0   16             0         0.0      112      263
# 16236        0   12             0         0.0      112      272
# 16237        0    0             0         0.0      112      283
#
#        goals_conceded  goals_scored  ict_index  influence  ...  saves  \
# 16233               2             0        1.7       17.2  ...      2
# 16234               2             0        1.2       12.0  ...      1
# 16235               1             0        2.3       23.0  ...      3
# 16236               2             0        2.8       27.8  ...      3
# 16237               0             0        0.0        0.0  ...      0
#
#       selected  team_a_score  team_h_score  threat  total_points  value  \
# 16233    14954             2             2       0             1     48
# ...

# %%
Chelsea.groupby('full')['goals_scored','red_cards','yellow_cards','creativity'].sum()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                    goals_scored  red_cards  yellow_cards  \
# full
# Addji Keaninkin Marc-Israel Guehi             0          0             0
# Andreas Christensen                           0          0             5
# Antonio R?diger                               2          0             3
# Armando Broja                                 0          0             0
# Billy Gilmour                                 0          0             0
# C?sar Azpilicueta                             2          0             0
# Callum Hudson-Odoi                            1          0             1
# Christian Pulisic                             5          0             0
# ...

# %%
#Fetching the data by teams
Liverpool = df11.loc[df11.team == 'Liverpool']
Liverpool.tail()
# Out:
#        assists  bps  clean_sheets  creativity  element  fixture  \
# 16291        0    0             0         0.0      194      245
# 16292        0    0             0         0.0      194      257
# 16293        0    0             0         0.0      194      266
# 16294        0    0             0         0.0      194      279
# 16295        0    0             0         0.0      194      286
#
#        goals_conceded  goals_scored  ict_index  influence  ...  saves  \
# 16291               0             0        0.0        0.0  ...      0
# 16292               0             0        0.0        0.0  ...      0
# 16293               0             0        0.0        0.0  ...      0
# 16294               0             0        0.0        0.0  ...      0
# 16295               0             0        0.0        0.0  ...      0
#
#       selected  team_a_score  team_h_score  threat  total_points  value  \
# 16291    17320             0             4       0             0     63
# ...

# %%
Liverpool.groupby('full')['goals_scored','red_cards','yellow_cards','creativity'].sum()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                 goals_scored  red_cards  yellow_cards  \
# full
# Adam Lallana                               1          0             1
# Adri?n San Miguel del Castillo             0          0             1
# Alex Oxlade-Chamberlain                    3          0             1
# Alisson Ramses Becker                      0          1             0
# Andrew Robertson                           1          0             1
# Andy Lonergan                              0          0             0
# Caoimhin Kelleher                          0          0             0
# Curtis Jones                               0          0             0
# Dejan Lovren                               0          0             1
# ...

# %%
#Fetching the data by teams
Burnley = df11.loc[df11.team == 'Burnley']
Burnley.tail()
# Out:
#        assists  bps  clean_sheets  creativity  element  fixture  \
# 15021        0    0             0         0.0       99      242
# 15022        0    0             0         0.0       99      259
# 15023        0    0             0         0.0       99      262
# 15024        0    0             0         0.0       99      276
# 15025        0    0             0         0.0       99      282
#
#        goals_conceded  goals_scored  ict_index  influence  ...  saves  \
# 15021               0             0        0.0        0.0  ...      0
# 15022               0             0        0.0        0.0  ...      0
# 15023               0             0        0.0        0.0  ...      0
# 15024               0             0        0.0        0.0  ...      0
# 15025               0             0        0.0        0.0  ...      0
#
#       selected  team_a_score  team_h_score  threat  total_points  value  \
# 15021      265             0             0       0             0     55
# ...

# %%
Burnley.groupby('full')['goals_scored','red_cards','yellow_cards','creativity'].sum()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                     goals_scored  red_cards  yellow_cards  \
# full
# Aaron Lennon                                   0          0             4
# Abd-Al-Ali Morakinyo Olaposi Koiki             0          0             0
# Anthony Driscoll-Glennon                       0          0             0
# Ashley Barnes                                  6          0             4
# Ashley Westwood                                2          0             9
# Bailey Peacock-Farrell                         0          0             0
# Ben Gibson                                     0          0             0
# Ben Mee                                        0          0             7
# ...

# %%
#Fetching the data by teams
Norwich = df11.loc[df11.team == 'Norwich']
Norwich.tail()
# Out:
#        assists  bps  clean_sheets  creativity  element  fixture  \
# 15530        0    0             0         0.0      290      247
# 15531        0    0             0         0.0      290      257
# 15532        0    0             0         0.0      290      270
# 15533        0    0             0         0.0      290      277
# 15534        0    0             0         0.0      290      288
#
#        goals_conceded  goals_scored  ict_index  influence  ...  saves  \
# 15530               0             0        0.0        0.0  ...      0
# 15531               0             0        0.0        0.0  ...      0
# 15532               0             0        0.0        0.0  ...      0
# 15533               0             0        0.0        0.0  ...      0
# 15534               0             0        0.0        0.0  ...      0
#
#       selected  team_a_score  team_h_score  threat  total_points  value  \
# 15530    43233             0             0       0             0     44
# ...

# %%
Norwich.groupby('full')['goals_scored','red_cards','yellow_cards','creativity'].sum()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                       goals_scored  red_cards  yellow_cards  creativity
# full
# Adam Idah                        0          0             0         1.5
# Akin Famewo                      0          0             0         0.0
# Alexander Tettey                 1          0             4       105.9
# Archie Mair                      0          0             0         0.0
# Ben Godfrey                      0          1             2        20.8
# Christoph Zimmermann             0          0             2        15.5
# Dennis Srbeny                    1          0             0         3.4
# Emiliano Buend?a                 0          0             4      1049.0
# Grant Hanley                     0          0             4         3.6
# ...

# %%
#Fetching the data by teams
Watford= df11.loc[df11.team =='Watford']
Watford.tail()
# Out:
#        assists  bps  clean_sheets  creativity  element  fixture  \
# 16107        0    0             0         0.0      370      249
# 16108        0    3             0        18.3      370      253
# 16109        0   13             0        29.2      370      267
# 16110        0    6             1        11.2      370      279
# 16111        0    6             0         4.6      370      284
#
#        goals_conceded  goals_scored  ict_index  influence  ...  saves  \
# 16107               0             0        0.0        0.0  ...      0
# 16108               1             0        4.2       13.6  ...      0
# 16109               3             0        5.4       24.6  ...      0
# 16110               0             0        4.3       10.0  ...      0
# 16111               1             0        3.2        6.6  ...      0
#
#       selected  team_a_score  team_h_score  threat  total_points  value  \
# 16107    21308             3             2       0             0     53
# ...

# %%
Watford.groupby('full')['goals_scored','red_cards','yellow_cards','creativity'].sum()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                goals_scored  red_cards  yellow_cards  \
# full
# Abdoulaye Doucour?                        4          0             8
# Adam Masina                               1          0             3
# Adrian Mariappa                           0          1             2
# Andre Gray                                2          0             1
# Ayotomiwa Dele-Bashiru                    0          0             0
# Ben Foster                                0          0             1
# Christian Kabasele                        0          2             1
# Craig Cathcart                            0          0             6
# Craig Dawson                              0          0             4
# ...

# %%
#Fetching the data by teams
Wolves= df11.loc[df11.team =='Wolves']
Wolves.tail()
# Out:
#        assists  bps  clean_sheets  creativity  element  fixture  \
# 16204        0   26             1         0.3      405      246
# 16205        0   23             1         0.6      405      260
# 16206        0   21             1         0.3      405      270
# 16207        0    8             0         0.6      405      278
# 16208        0   27             1         0.4      405      290
#
#        goals_conceded  goals_scored  ict_index  influence  ...  saves  \
# 16204               0             0        1.6       16.0  ...      0
# 16205               0             0        3.3       15.0  ...      0
# 16206               0             0        1.3       13.0  ...      0
# 16207               2             0        2.0       17.8  ...      0
# 16208               0             0        2.1       20.6  ...      0
#
#       selected  team_a_score  team_h_score  threat  total_points  value  \
# 16204   143209             0             0       0             6     47
# ...

# %%
Wolves.groupby('full')['goals_scored','red_cards','yellow_cards','creativity'].sum()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                         goals_scored  red_cards  yellow_cards  \
# full
# Adama Traor?                                       4          0             0
# Bernard Ashley-Seal                                0          0             0
# Bruno Andr? Cavaco Jordao                          0          0             0
# Conor Coady                                        0          0             3
# Daniel Castelo Podence                             0          0             0
# Diogo Jota                                         6          0             3
# H?lder Costa                                       0          0             0
# Ivan Cavaleiro                                     0          0             0
# ...

# %%
#Fetching the data by teams
Everton= df11.loc[df11.team =='Everton']
Everton.tail()
# Out:
#        assists  bps  clean_sheets  creativity  element  fixture  \
# 16349        0   31             0         0.6      142      249
# 16350        0   11             0         0.3      142      255
# 16351        1   21             0        11.3      142      261
# 16352        0    0             0         0.0      142      274
# 16353        0    0             0         0.0      142      283
#
#        goals_conceded  goals_scored  ict_index  influence  ...  saves  \
# 16349               2             2       14.4       87.6  ...      0
# 16350               1             0        1.6        7.6  ...      0
# 16351               3             0        5.8       27.0  ...      0
# 16352               0             0        0.0        0.0  ...      0
# 16353               0             0        0.0        0.0  ...      0
#
#       selected  team_a_score  team_h_score  threat  total_points  value  \
# 16349   148560             3             2      56            15     53
# ...

# %%
Everton.groupby('full')['goals_scored','red_cards','yellow_cards','creativity'].sum()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                 goals_scored  red_cards  yellow_cards  \
# full
# Ademola Lookman                            0          0             0
# Alex Iwobi                                 1          0             0
# Andr? Filipe Tavares Gomes                 0          0             5
# Anthony Gordon                             0          0             0
# Beni Baningime                             0          0             0
# Bernard An?cio Caldeira Duarte             3          0             2
# Cenk Tosun                                 1          0             0
# Djibril Sidib?                             0          0             3
# Dominic Calvert-Lewin                     13          0             7
# ...

# %%
#Fetching the data by teams
Arsenal= df11.loc[df11.team =='Arsenal']
Arsenal.tail()
# Out:
#        assists  bps  clean_sheets  creativity  element  fixture  \
# 15656        0    0             0         0.0      585      238
# 15657        0    0             0         0.0      585      242
# 15658        0    0             0         0.0      585      251
# 15659        0    0             0         0.0      585      261
# 15660        0    0             0         0.0      585      281
#
#        goals_conceded  goals_scored  ict_index  influence  ...  saves  \
# 15656               0             0        0.0        0.0  ...      0
# 15657               0             0        0.0        0.0  ...      0
# 15658               0             0        0.0        0.0  ...      0
# 15659               0             0        0.0        0.0  ...      0
# 15660               0             0        0.0        0.0  ...      0
#
#       selected  team_a_score  team_h_score  threat  total_points  value  \
# 15656      394             2             2       0             0     45
# ...

# %%
Arsenal.groupby('full')['goals_scored','red_cards','yellow_cards','creativity'].sum()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                   goals_scored  red_cards  yellow_cards  \
# full
# Ainsley Maitland-Niles                       0          1             3
# Alexandre Lacazette                          7          0             5
# Bernd Leno                                   0          0             2
# Bukayo Saka                                  0          0             4
# C?dric Soares                                0          0             0
# Calum Chambers                               1          0             5
# Carl Jenkinson                               0          0             0
# Daniel Ceballos Fern?ndez                    0          0             0
# David Luiz Moreira Marinho                   2          1             4
# ...

# %%
#Fetching the data by teams
WestHam = df11.loc[df11.team == 'West Ham']
WestHam.tail()
# Out:
#        assists  bps  clean_sheets  creativity  element  fixture  \
# 16262        0    0             0         0.0      383      250
# 16263        0    0             0         0.0      383      256
# 16264        0    0             0         0.0      383      266
# 16265        0    0             0         0.0      383      280
# 16266        0    0             0         0.0      383      281
#
#        goals_conceded  goals_scored  ict_index  influence  ...  saves  \
# 16262               0             0        0.0        0.0  ...      0
# 16263               0             0        0.0        0.0  ...      0
# 16264               0             0        0.0        0.0  ...      0
# 16265               0             0        0.0        0.0  ...      0
# 16266               0             0        0.0        0.0  ...      0
#
#       selected  team_a_score  team_h_score  threat  total_points  value  \
# 16262   380813             3             3       0             0     39
# ...

# %% [markdown]
# I know you didnt really see visualizations in this kernel,but i felt the statistics i did
#
# were well explanatory,thats why
#
#
# SO I WOULD STOP HERE FOR NOW,BECAUSE I KNOW I HAVE GIVEN YOU MOST OF THE MAJOR INFORMATIONS ABOUT THE EPL
#
# AND I DONT WANT TO MAKE IT LOOK LIKE THEY HAVE CONCLUDED THE SEASON YET...
#
# SO I WOULD DEFINITELY GET THE DATASET AFTER THE SEASON ENDS...
#
# SO I CAN DO A COMPLETE EDA .......
#
#
# THANKS FOR VIEWING
#
# YOU CAN ALSO CHECK MY
#
#
# PREDICTIONS FOR THE EPL IN MY NEXT KERNEL......
